# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo12n.pt")

# %%
# Export the model to NCNN format
model.export(format="ncnn", imgsz=640)  # creates 'yolov12n_ncnn_model'
# Out:
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.1+cpu CPU (aarch64)
# YOLOv12n summary (fused): 159 layers, 2,590,824 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo12n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.3 MB)
#
# NCNN: starting export with NCNN 1.0.20250916 and PNNX 20251119...
# pnnxparam = yolo12n_ncnn_model/model.pnnx.param
# pnnxbin = yolo12n_ncnn_model/model.pnnx.bin
# pnnxpy = yolo12n_ncnn_model/model_pnnx.py
# pnnxonnx = yolo12n_ncnn_model/model.pnnx.onnx
# ncnnparam = yolo12n_ncnn_model/model.ncnn.param
# ncnnbin = yolo12n_ncnn_model/model.ncnn.bin
# ncnnpy = yolo12n_ncnn_model/model_ncnn.py
# fp16 = 0
# optlevel = 2
# device = cpu
# inputshape = [1,3,640,640]f32
# inputshape2 =
# customop =
# moduleop =
# get inputshape from traced inputs
# inputshape = [1,3,640,640]f32
# ############# pass_level0
# inline module = torch.nn.modules.linear.Identity
# inline module = ultralytics.nn.modules.block.A2C2f
# ...
