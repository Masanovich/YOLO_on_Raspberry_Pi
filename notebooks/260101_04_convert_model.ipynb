# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo12n.pt")

# %%
# Export the model to NCNN format
model.export(format="ncnn", imgsz=320)  # creates 'yolov12n_ncnn_model'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (Intel Core i5-10400 2.90GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv12n summary (fused): 159 layers, 2,590,824 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo12n.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 84, 2100) (5.3 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Using Python 3.12.3 environment at: /home/masayuki/Documents/Projects/Python/YOLO_camera/.venv
# Resolved 1 package in 228ms
# ...
#  Downloaded ncnn
# Prepared 1 package in 627ms
# Installed 1 package in 2ms
#  + ncnn==1.0.20250916
#
# requirements: AutoUpdate success ✅ 1.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# requirements: Ultralytics requirement ['pnnx'] not found, attempting AutoUpdate...
# ...
